# %% [markdown]
# Scale-Invariant Feature Transform
#
# sources:
#
# https://opencv24-python-tutorials.readthedocs.io/en/latest/py_tutorials/py_feature2d/py_sift_intro/py_sift_intro.html
#
# https://www.analyticsvidhya.com/blog/2019/10/detailed-guide-powerful-sift-technique-image-matching-python/
#
# https://docs.opencv.org/3.4.15/d7/d60/classcv_1_1SIFT.html

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image_paths = [
    "../data/2013_CrossFit_Games_-_Stadium_relay.jpg",
    "../data/pedestrian.jpg"
]

# %%
for image_path in image_paths:
    img = cv2.imread(image_path)
    img = cv2.resize(img, dsize=(400, round(400*img.shape[0]/img.shape[1])))
    gray= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    sift = cv2.SIFT_create()
    kp = sift.detect(gray, None)

    img = cv2.drawKeypoints(gray, kp, gray)
    fig, ax = plt.subplots()
    ax.imshow(img)
    plt.show()
